# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Rectangle

ball_x_coordinate = np.random.normal(loc=1.41, scale=0.4, size=(60, 1))
ball_x_coordinate = pd.DataFrame(ball_x_coordinate)
ball_y_coordinate = np.random.normal(loc=12, scale=2, size=(60, 1))
ball_y_coordinate = pd.DataFrame(ball_y_coordinate)

wicket_hitting = np.random.choice(a=[0, 1], size=60, p=[0.6, 0.4])
wicket_hitting = pd.DataFrame(wicket_hitting)
speeds = np.random.normal(loc=140, scale=8, size=(60, 1))
speeds = pd.DataFrame(speeds)
balls_xy = pd.concat([ball_x_coordinate, ball_y_coordinate, wicket_hitting, speeds], axis=1)

w_dict = {1: 'Wickets_hitting', 0: 'Not_hitting'}
balls_xy.iloc[:, 2] = balls_xy.iloc[:, 2].replace(w_dict)
balls_xy.columns
balls_xy.rename(columns={0: 'ball_x_coordinate', 1: 'ball_y_coordinate'}, inplace=True)

spadl_config = {
    "length": 3.66,
    "width": 22.56,
    "origin_x": 0,
    "origin_y": 0,
}
plt.rcParams['figure.figsize'] = [2, 6]

def _plot_rectangle(x1, y1, x2, y2, ax, color):
    ax.plot([x1, x1], [y1, y2], color=color)
    ax.plot([x2, x2], [y1, y2], color=color)
    ax.plot([x1, x2], [y1, y1], color=color)
    ax.plot([x1, x2], [y2, y2], color=color)
    ax.set_facecolor("green")


def pitch(ax=None, linecolor="green", fieldcolor=None, alpha=1, figsize=None, pitch_config=spadl_config, show=True):
    cfg = pitch_config

    if ax is None:
        fig = plt.figure()
        ax = fig.gca()

    x1, y1, x2, y2 = (
        cfg["origin_x"],
        cfg["origin_y"],
        cfg["origin_x"] + cfg["length"],
        cfg["origin_y"] + cfg["width"],
    )

    _plot_rectangle(x1, y1, x2, y2, ax=ax, color=linecolor)

    # lower crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 1.22
    y2 = 2.44
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    # upper crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 20.12
    y2 = 21.34
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    plt.axvline(x=0.51, color='white')
    plt.axvline(x=3.15, color='white')
    plt.axhline(y=20.12, color='white', linestyle='-')
    plt.axhline(y=2.44, color='white', linestyle='-')

    if show:
        plt.show()

    return ax

pitch(show=False)

# Scatter plot of ball coordinates
sns.scatterplot(data=balls_xy, x='ball_x_coordinate', y='ball_y_coordinate', hue='Wickets_hitting', palette='hot', style='Wickets_hitting')

# KDE plot
# sns.kdeplot(data=balls_xy, x=balls_xy.iloc[:, 0], y=balls_xy.iloc[:, 1], cmap="hot")

pitch(show=False)

# Scatter plot with color representing ball speed and color bar
plt.rcParams['figure.figsize'] = [2.5, 6]

ax = sns.scatterplot(data=balls_xy, x='ball_x_coordinate', y='ball_y_coordinate', hue='speed', palette='hot')

norm = plt.Normalize(balls_xy['speed'].min(), balls_xy['speed'].max())
sm = plt.cm.ScalarMappable(cmap="hot", norm=norm)
sm.set_array([])

# Remove the legend and add a colorbar
ax.get_legend().remove()
ax.figure.colorbar(sm)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 82
#      79 pitch(show=False)
#      81 # Scatter plot of ball coordinates
# ---> 82 sns.scatterplot(data=balls_xy, x='ball_x_coordinate', y='ball_y_coordinate', hue='Wickets_hitting', palette='hot', style='Wickets_hitting')
#      84 # KDE plot
#      85 # sns.kdeplot(data=balls_xy, x=balls_xy.iloc[:, 0], y=balls_xy.iloc[:, 1], cmap="hot")
#      87 pitch(show=False)
#
# File ~\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Load custom CSV file with x and y coordinates
custom_data = pd.read_csv('Height.csv')  # Replace 'your_custom_data.csv' with your actual CSV file

spadl_config = {
    "length": 3.66,
    "width": 22.56,
    "origin_x": 0,
    "origin_y": 0,
}
plt.rcParams['figure.figsize'] = [2, 6]

def _plot_rectangle(x1, y1, x2, y2, ax, color):
    ax.plot([x1, x1], [y1, y2], color=color)
    ax.plot([x2, x2], [y1, y2], color=color)
    ax.plot([x1, x2], [y1, y1], color=color)
    ax.plot([x1, x2], [y2, y2], color=color)
    ax.set_facecolor("green")

def pitch(ax=None, linecolor="green", fieldcolor=None, alpha=1, figsize=None, pitch_config=spadl_config, show=True):
    cfg = pitch_config

    if ax is None:
        fig = plt.figure()
        ax = fig.gca()

    x1, y1, x2, y2 = (
        cfg["origin_x"],
        cfg["origin_y"],
        cfg["origin_x"] + cfg["length"],
        cfg["origin_y"] + cfg["width"],
    )

    _plot_rectangle(x1, y1, x2, y2, ax=ax, color=linecolor)

    # lower crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 1.22
    y2 = 2.44
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    # upper crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 20.12
    y2 = 21.34
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    plt.axvline(x=0.51, color='white')
    plt.axvline(x=3.15, color='white')
    plt.axhline(y=20.12, color='white', linestyle='-')
    plt.axhline(y=2.44, color='white', linestyle='-')

    if show:
        plt.show()

    return ax

pitch(show=False)

# Scatter plot of custom x and y coordinates
plt.scatter(custom_data['x'], custom_data['y'])
plt.title('Scatter Plot of Custom Coordinates')
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Load custom XLS file with x and y coordinates
custom_data = pd.read_csv('Height.csv')  # Replace 'your_custom_data.xlsx' with your actual XLS file

spadl_config = {
    "length": 3.66,
    "width": 22.56,
    "origin_x": 0,
    "origin_y": 0,
}
plt.rcParams['figure.figsize'] = [2, 6]

def _plot_rectangle(x1, y1, x2, y2, ax, color):
    ax.plot([x1, x1], [y1, y2], color=color)
    ax.plot([x2, x2], [y1, y2], color=color)
    ax.plot([x1, x2], [y1, y1], color=color)
    ax.plot([x1, x2], [y2, y2], color=color)
    ax.set_facecolor("green")

def pitch(ax=None, linecolor="green", fieldcolor=None, alpha=1, figsize=None, pitch_config=spadl_config, show=True):
    cfg = pitch_config

    if ax is None:
        fig = plt.figure()
        ax = fig.gca()

    x1, y1, x2, y2 = (
        cfg["origin_x"],
        cfg["origin_y"],
        cfg["origin_x"] + cfg["length"],
        cfg["origin_y"] + cfg["width"],
    )

    _plot_rectangle(x1, y1, x2, y2, ax=ax, color=linecolor)

    # lower crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 1.22
    y2 = 2.44
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    # upper crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 20.12
    y2 = 21.34
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    plt.axvline(x=0.51, color='white')
    plt.axvline(x=3.15, color='white')
    plt.axhline(y=20.12, color='white', linestyle='-')
    plt.axhline(y=2.44, color='white', linestyle='-')

    if show:
        plt.show()

    return ax

pitch(show=False)

# Convert pixels to millimeters
custom_data['x_mm'] = pixels_to_mm(custom_data['x'], dpi)
custom_data['y_mm'] = pixels_to_mm(custom_data['y'], dpi)

# Scatter plot of custom x and y coordinates in millimeters
plt.scatter(custom_data['x_mm'], custom_data['y_mm'])
plt.title('Scatter Plot of Custom Coordinates (in mm)')
plt.xlabel('X Coordinate (mm)')
plt.ylabel('Y Coordinate (mm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 66
#      63 pitch(show=False)
#      65 # Convert pixels to millimeters
# ---> 66 custom_data['x_mm'] = pixels_to_mm(custom_data['x'], dpi)
#      67 custom_data['y_mm'] = pixels_to_mm(custom_data['y'], dpi)
#      69 # Scatter plot of custom x and y coordinates in millimeters
#
# NameError: name 'pixels_to_mm' is not defined

# %% [markdown]
# #### import pandas as pd
# import matplotlib.pyplot as plt
# from matplotlib.patches import Rectangle
#
# # Function to convert pixels to millimeters
# def pixels_to_mm(pixels, dpi):
#     mm_per_inch = 25.4
#     return (pixels / dpi) * mm_per_inch
#
# # Load custom XLS file with x and y coordinates
# custom_data = pd.read_csv('Height.csv')  # Replace 'your_custom_data.xlsx' with your actual XLS file
#
# # Set dpi value (replace 300 with the actual dpi value of your data)
# dpi = 300
#
# spadl_config = {
#     "length": 3.66,
#     "width": 22.56,
#     "origin_x": 0,
#     "origin_y": 0,
# }
# plt.rcParams['figure.figsize'] = [2, 6]
#
# def _plot_rectangle(x1, y1, x2, y2, ax, color):
#     ax.plot([x1, x1], [y1, y2], color=color)
#     ax.plot([x2, x2], [y1, y2], color=color)
#     ax.plot([x1, x2], [y1, y1], color=color)
#     ax.plot([x1, x2], [y2, y2], color=color)
#     ax.set_facecolor("green")
#
# def pitch(ax=None, linecolor="green", fieldcolor=None, alpha=1, figsize=None, pitch_config=spadl_config, show=True):
#     cfg = pitch_config
#
#     if ax is None:
#         fig = plt.figure()
#         ax = fig.gca()
#
#     x1, y1, x2, y2 = (
#         cfg["origin_x"],
#         cfg["origin_y"],
#         cfg["origin_x"] + cfg["length"],
#         cfg["origin_y"] + cfg["width"],
#     )
#
#     _plot_rectangle(x1, y1, x2, y2, ax=ax, color=linecolor)
#
#     # lower crease rectangle
#     x1 = 0.51
#     x2 = 3.15
#     y1 = 1.22
#     y2 = 2.44
#     _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')
#
#     # upper crease rectangle
#     x1 = 0.51
#     x2 = 3.15
#     y1 = 20.12
#     y2 = 21.34
#     _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')
#
#     plt.axvline(x=0.51, color='white')
#     plt.axvline(x=3.15, color='white')
#     plt.axhline(y=20.12, color='white', linestyle='-')
#     plt.axhline(y=2.44, color='white', linestyle='-')
#
#     if show:
#         plt.show()
#
#     return ax
#
# pitch(show=False)
#
# # Convert pixels to millimeters
# custom_data['x_mm'] = pixels_to_mm(custom_data['x'], dpi)
# custom_data['y_mm'] = pixels_to_mm(custom_data['y'], dpi)
#
# # Scatter plot of custom x and y coordinates in millimeters
# plt.scatter(custom_data['x_mm'], custom_data['y_mm'])
# plt.title('Scatter Plot of Custom Coordinates (in mm)')
# plt.xlabel('X Coordinate (mm)')
# plt.ylabel('Y Coordinate (mm)')
# plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

# Function to convert pixels to millimeters
def pixels_to_mm(pixels, dpi):
    mm_per_inch = 25.4
    return (pixels / dpi) * mm_per_inch

# Load custom XLS file with x and y coordinates
custom_data = pd.read_csv('Height.csv')  # Replace 'your_custom_data.xlsx' with your actual XLS file

# Set dpi value (replace 300 with the actual dpi value of your data)
dpi = 300

spadl_config = {
    "length": 3.66,
    "width": 22.56,
    "origin_x": 0,
    "origin_y": 0,
}
plt.rcParams['figure.figsize'] = [2, 6]

def _plot_rectangle(x1, y1, x2, y2, ax, color):
    ax.plot([x1, x1], [y1, y2], color=color)
    ax.plot([x2, x2], [y1, y2], color=color)
    ax.plot([x1, x2], [y1, y1], color=color)
    ax.plot([x1, x2], [y2, y2], color=color)
    ax.set_facecolor("green")

def pitch(ax=None, linecolor="green", fieldcolor=None, alpha=1, figsize=None, pitch_config=spadl_config, show=True):
    cfg = pitch_config

    if ax is None:
        fig = plt.figure()
        ax = fig.gca()

    x1, y1, x2, y2 = (
        cfg["origin_x"],
        cfg["origin_y"],
        cfg["origin_x"] + cfg["length"],
        cfg["origin_y"] + cfg["width"],
    )

    _plot_rectangle(x1, y1, x2, y2, ax=ax, color=linecolor)

    # lower crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 1.22
    y2 = 2.44
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    # upper crease rectangle
    x1 = 0.51
    x2 = 3.15
    y1 = 20.12
    y2 = 21.34
    _plot_rectangle(x1, y1, x2, y2, ax=ax, color='white')

    plt.axvline(x=0.51, color='white')
    plt.axvline(x=3.15, color='white')
    plt.axhline(y=20.12, color='white', linestyle='-')
    plt.axhline(y=2.44, color='white', linestyle='-')

    if show:
        plt.show()

    return ax

pitch(show=False)

# Convert pixels to millimeters
custom_data['x_mm'] = pixels_to_mm(custom_data['x'], dpi)
custom_data['y_mm'] = pixels_to_mm(custom_data['y'], dpi)

# Scatter plot of custom x and y coordinates in millimeters
plt.scatter(custom_data['x_mm'], custom_data['y_mm'])
plt.title('Scatter Plot of Custom Coordinates (in mm)')
plt.xlabel('X Coordinate (mm)')
plt.ylabel('Y Coordinate (mm)')
plt.show()

# %%
pip install PyQt5
# Out:
# ...
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.8 MB 163.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/6.8 MB 163.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/6.8 MB 163.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/6.8 MB 163.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/6.8 MB 163.8 kB/s eta 0:00:42
#    ---------------------------------------- 0.0/6.8 MB 89.3 kB/s eta 0:01:17
#    ---------------------------------------- 0.1/6.8 MB 131.3 kB/s eta 0:00:52
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

# %matplotlib inline

def calculate_pitch_map_coordinates(length_x, length_y, origin_x, origin_y, is_1s, is_2s, is_4s, is_6s, is_0s, is_batwkts):
    x_axis = calculate_pitch_map_xaxis(length_x, length_y, origin_x)
    y_axis = calculate_pitch_map_yaxis(length_y, origin_y)
    
    if is_1s == 1:
        color = 'goldenrod'
    elif is_2s == 1:
        color = 'blue'
    elif is_4s == 1:
        color = 'darkblue'
    elif is_6s == 1:
        color = 'red'
    elif is_0s == 1:
        color = 'black'
    elif is_batwkts == 1:
        color = 'azure'
    else:
        color = 'brown'
    
    return x_axis, y_axis, color

def calculate_pitch_map_xaxis(length_x, length_y, origin_x):
    return ((pitch_map_start_x2p - pitch_map_start_x1p) / old_reg_xlen) * length_x + pitch_map_start_x1p

def calculate_pitch_map_yaxis(length_y, origin_y):
    return pitch_map_height - (((pitch_map_stump_y - pitch_map_start_y) / (old_reg_stump_y - old_reg_start_y)) * (length_y - old_reg_start_y) + pitch_map_start_y)

def main():
    csv_path = "Length2.csv"  
    data = pd.read_csv(csv_path)

    batsman_name = input("Enter the batsman's name: ")

    if batsman_name in data['StrikerName'].values:
        batting_type = data.loc[data['StrikerName'] == batsman_name, 'BattingType'].iloc[0]

        if batting_type == 'RHB':
            image_path = 'pitchR.jpg' 
        elif batting_type == 'LHB':
            image_path = 'pitchL.jpg'  

        img = Image.open(image_path)
        img_array = plt.imread(image_path)
        height, width, _ = img_array.shape
        origin_x, origin_y = 0, 0
        plt.imshow(img_array, extent=[0, width, 0, height])

        spin_or_pace = input("Enter '1' for pace, '2' for spin, or '3' for both : ")

        if spin_or_pace == '1':
            pace_type = input("Enter '1' for RAP or '2' for LAP or '3' for Both: ")
            filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 1) & (data['BowlerType'] == int(pace_type))]
        elif spin_or_pace == '2':
            spin_type = input("Enter '3' for RAO, '4' for SLAO, '5' for RALB, '6' for LAC, or '7' for all: ")
            if spin_type == '7':
                filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 2)]
            else:
                filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 2) & (data['BowlerType'] == int(spin_type))]
        else:
            filtered_data = data[data['StrikerName'] == batsman_name]

        specific_runs = input("Enter specific runs (0s, 1s, 2s, 3s, 4s, 6s, batwkts) or 'all' for all runs: ")

        if specific_runs == 'all':
            pass
        else:
            filtered_data = filtered_data[filtered_data[specific_runs] == 1]

        if not filtered_data.empty:
            for i in range(len(filtered_data)):
                pitch_x, pitch_y, point_color = calculate_pitch_map_coordinates(filtered_data['X'].iloc[i], filtered_data['Y'].iloc[i], origin_x, origin_y, 
                                                                    filtered_data['1s'].iloc[i], filtered_data['2s'].iloc[i], filtered_data['4s'].iloc[i], filtered_data['6s'].iloc[i],
                                                                    filtered_data['0s'].iloc[i], filtered_data['batwkts'].iloc[i])
                plt.scatter(pitch_x, pitch_y, marker='o', color=point_color)

            plt.title("PitchMap of " + batsman_name)
            plt.xticks([])
            plt.yticks([])

            legend_elements = [
                plt.Line2D([0], [0], marker='o', color='w', label='0s', markerfacecolor='black', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='1s', markerfacecolor='goldenrod', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='2s', markerfacecolor='blue', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='3s', markerfacecolor='green', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='4s', markerfacecolor='darkblue', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='6s', markerfacecolor='red', markersize=10),
                plt.Line2D([0], [0], marker='o', color='w', label='Out', markerfacecolor='azure', markersize=10),
            ]
            plt.legend(handles=legend_elements, loc='lower center', bbox_to_anchor=(0.48, 0.05), ncol=7, prop={'size':8})
            #plt.legend(handles=legend_elements, loc='upper right')
            
            plt.show()
        else:
            print("No data found for the selected batsman and type (spin or pace).")
    else:
        print(f"Batsman with name '{batsman_name}' not found in the data.")
old_reg_start_y = 0
old_reg_stump_y = 101
old_reg_2m_y = 263
old_reg_4m_y = 439
old_reg_6m_y = 620
old_reg_8m_y = 808
old_reg_10m_y = 1005
old_reg_end_y = 1788
old_reg_xlen = 364

pitch_map_height = 600
pitch_map_weight = 1080
pitch_map_start_y = 153
pitch_map_stump_y = 178
pitch_map_2m_y = 208
pitch_map_4m_y = 253
pitch_map_6m_y = 298
pitch_map_8m_y = 352
pitch_map_10m_y = 408
pitch_map_end_y = 489

pitch_map_start_x1p = 344
pitch_map_start_x2p = 704
pitch_map_stump_x1p = 339
pitch_map_stump_x2p = 709
pitch_map_2m_x1p = 332
pitch_map_2m_x2p = 714
pitch_map_4m_x1p = 323
pitch_map_4m_x2p = 722
pitch_map_6m_x1p = 316 
pitch_map_6m_x2p = 729
pitch_map_8m_x1p = 306
pitch_map_8m_x2p = 742
pitch_map_10m_x1p = 294
pitch_map_10m_x2p = 752
pitch_map_end_x1p = 277
pitch_map_end_x2p = 769

if __name__ == "_main_":
    main()


    ###############################################
                                                    #
                                                        #
                                                            #
                                                                #
                                                                    #
                                                                #
                                                            #
                                                        #
                                                    #
    ###############################################

# %%
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

# %matplotlib inline

def calculate_pitch_map_coordinates(length_x, length_y, origin_x, origin_y, is_1s, is_2s, is_4s, is_6s, is_0s, is_batwkts):
    x_axis = calculate_pitch_map_xaxis(length_x, length_y, origin_x)
    y_axis = calculate_pitch_map_yaxis(length_y, origin_y)
    
    if is_1s == 1:
        color = 'goldenrod'
    elif is_2s == 1:
        color = 'blue'
    elif is_4s == 1:
        color = 'darkblue'
    elif is_6s == 1:
        color = 'red'
    elif is_0s == 1:
        color = 'black'
    elif is_batwkts == 1:
        color = 'azure'
    else:
        color = 'brown'
    
    return x_axis, y_axis, color

def calculate_pitch_map_xaxis(length_x, length_y, origin_x):
    return ((pitch_map_start_x2p - pitch_map_start_x1p) / old_reg_xlen) * length_x + pitch_map_start_x1p

def calculate_pitch_map_yaxis(length_y, origin_y):
    return pitch_map_height - (((pitch_map_stump_y - pitch_map_start_y) / (old_reg_stump_y - old_reg_start_y)) * (length_y - old_reg_start_y) + pitch_map_start_y)

def main():
    csv_path = "Ausvsnz.csv"  
    data = pd.read_csv(csv_path)

    batsman_name = input("Enter the batsman's name: ")

    if batsman_name in data['StrikerName'].values:
        batting_type = data.loc[data['StrikerName'] == batsman_name, 'BattingType'].iloc[0]

        if batting_type == 'RHB':
            image_path = 'pitchR.jpg' 
        elif batting_type == 'LHB':
            image_path = 'pitchL.jpg'  

        img = Image.open(image_path)
        img_array = plt.imread(image_path)
        height, width, _ = img_array.shape
        origin_x, origin_y = 0, 0
        plt.imshow(img_array, extent=[0, width, 0, height])

        spin_or_pace = input("Enter '1' for pace, '2' for spin, or '3' for both : ")

        if spin_or_pace == '1':
            pace_type = input("Enter '1' for RAP or '2' for LAP or '3' for Both: ")
            filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 1) & (data['BowlerType'] == int(pace_type))]
        elif spin_or_pace == '2':
            spin_type = input("Enter '3' for RAO, '4' for SLAO, '5' for RALB, '6' for LAC, or '7' for all: ")
            if spin_type == '7':
                filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 2)]
            else:
                filtered_data = data[(data['StrikerName'] == batsman_name) & (data['PaceOrSpin'] == 2) & (data['BowlerType'] == int(spin_type))]
        else:
            filtered_data = data[data['StrikerName'] == batsman_name]

        specific_runs = input("Enter specific runs (0s, 1s, 2s, 3s, 4s, 6s, batwkts) or 'all' for all runs: ")

        if specific_runs == 'all':
            pass
        else:
            filtered_data = filtered_data[filtered_data[specific_runs] == 1]

        if not filtered_data.empty:
            for i in range(len(filtered_data)):
                pitch_x, pitch_y, point_color = calculate_pitch_map_coordinates(filtered_data['X'].iloc[i], filtered_data['Y'].iloc[i], origin_x, origin_y, 
                                                                    filtered_data['1s'].iloc[i], filtered_data['2s'].iloc[i], filtered_data['4s'].iloc[i], filtered_data['6s'].iloc[i],
                                                                    filtered_data['0s'].iloc[i], filtered_data['batwkts'].iloc[i])
                plt.scatter(pitch_x, pitch_y, marker='.', color=point_color)

            plt.title("PitchMap of " + batsman_name)
            plt.xticks([])
            plt.yticks([])

            legend_elements = [
                plt.Line2D([0], [0], marker='.', color='w', label='0s', markerfacecolor='black', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='1s', markerfacecolor='goldenrod', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='2s', markerfacecolor='blue', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='3s', markerfacecolor='green', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='4s', markerfacecolor='darkblue', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='6s', markerfacecolor='red', markersize=10),
                plt.Line2D([0], [0], marker='.', color='w', label='Out', markerfacecolor='azure', markersize=10),
            ]
            plt.legend(handles=legend_elements, loc='lower center', bbox_to_anchor=(0.48, 0.05), ncol=7, prop={'size':8})
            
            plt.show()
        else:
            print("No data found for the selected batsman and type (spin or pace).")
    else:
        print(f"Batsman with name '{batsman_name}' not found in the data.")

old_reg_start_y = 0
old_reg_stump_y = 101
old_reg_2m_y = 263
old_reg_4m_y = 439
old_reg_6m_y = 620
old_reg_8m_y = 808
old_reg_10m_y = 1005
old_reg_end_y = 1788
old_reg_xlen = 364

pitch_map_height = 600
pitch_map_weight = 1080
pitch_map_start_y = 153
pitch_map_stump_y = 178
pitch_map_2m_y = 208
pitch_map_4m_y = 253
pitch_map_6m_y = 298
pitch_map_8m_y = 352
pitch_map_10m_y = 408
pitch_map_end_y = 489

pitch_map_start_x1p = 344
pitch_map_start_x2p = 704
pitch_map_stump_x1p = 339
pitch_map_stump_x2p = 709
pitch_map_2m_x1p = 332
pitch_map_2m_x2p = 714
pitch_map_4m_x1p = 323
pitch_map_4m_x2p = 722
pitch_map_6m_x1p = 316 
pitch_map_6m_x2p = 729
pitch_map_8m_x1p = 306
pitch_map_8m_x2p = 742
pitch_map_10m_x1p = 294
pitch_map_10m_x2p = 752
pitch_map_end_x1p = 277
pitch_map_end_x2p = 769

if __name__ == "__main__":
    main()

# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.6 MB 10.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/8.6 MB 8.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.6 MB 6.5 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.6 MB 7.6 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.6 MB 6.8 MB/s eta 0:00:02
#    --------- ------------------------------ 2.0/8.6 MB 7.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.3/8.6 MB 7.0 MB/s eta 0:00:01
#    ------------ --------------------------- 2.8/8.6 MB 7.3 MB/s eta 0:00:01
#    -------------- ------------------------- 3.1/8.6 MB 7.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.5/8.6 MB 7.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.7/8.6 MB 7.2 MB/s eta 0:00:01
# ...
